# %% [markdown]
# ### 국가통계포털(KOSIS)
# * http://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1KE10081&vw_cd=MT_ZTITLE&list_id=JF&seqNo=&lang_mode=ko&language=kor&obj_var_id=&itm_id=&conn_path=MT_ZTITLE

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

if os.name == 'posix':  # Mac
    sns.set(font='AppleGeothic')
elif os.name == 'nt':   # windows
    sns.set(font='Malgun Gothic')
    
# 폰트의 주변이 흐릿하게 보이는 것을 방지
# %config lnlineBackend.figure_format = 'retina'

df_raw = pd.read_csv('../data/국가_대륙_별_상품군별_온라인쇼핑_해외직접판매액_20220727105731.csv',encoding='CP949')
df_raw
# Out:
#     국가(대륙)별          상품군별   판매유형별  2021.4/4  2022.1/4 p)
# 0        합계            합계       계    926718       567701
# 1        합계            합계     면세점    681168       363520
# 2        합계            합계  면세점 이외    245550       204181
# 3        합계    컴퓨터 및 주변기기       계      2707         2449
# 4        합계    컴퓨터 및 주변기기     면세점         0            0
# ..      ...           ...     ...       ...          ...
# 445      기타  생활용품 및 자동차용품     면세점         0            0
# 446      기타  생활용품 및 자동차용품  면세점 이외      1081          267
# 447      기타           기 타       계      1076         2309
# 448      기타           기 타     면세점         0            0
# 449      기타           기 타  면세점 이외      1076         2309
#
# [450 rows x 5 columns]

# %%
df_raw.shape
# Out:
# (450, 5)

# %%
df_raw['국가(대륙)별'].value_counts()
# Out:
# 합계            45
# 미국            45
# 중국            45
# 일본            45
# 아세안(ASEAN)    45
# 유럽연합(EU)      45
# 중동            45
# 중남미           45
# 대양주           45
# 기타            45
# Name: 국가(대륙)별, dtype: int64

# %%
df_raw[df_raw['국가(대륙)별'] == '미국'].reset_index(drop=True)
# Out:
#    국가(대륙)별          상품군별   판매유형별  2021.4/4  2022.1/4 p)
# 0       미국            합계       계     67036        50156
# 1       미국            합계     면세점       108          127
# 2       미국            합계  면세점 이외     66928        50029
# 3       미국    컴퓨터 및 주변기기       계       731          656
# 4       미국    컴퓨터 및 주변기기     면세점         0            0
# 5       미국    컴퓨터 및 주변기기  면세점 이외       731          656
# 6       미국    가전·전자·통신기기       계       699          209
# 7       미국    가전·전자·통신기기     면세점         1            0
# 8       미국    가전·전자·통신기기  면세점 이외       698          209
# 9       미국         소프트웨어       계       323           92
# 10      미국         소프트웨어     면세점         0            0
# 11      미국         소프트웨어  면세점 이외       323           92
# 12      미국           서 적       계      3073         2986
# 13      미국           서 적     면세점         0            0
# 14      미국           서 적  면세점 이외      3073         2986
# 15      미국         사무·문구       계       334          804
# 16      미국         사무·문구     면세점         0            0
# 17      미국         사무·문구  면세점 이외       334          804
# 18      미국     음반·비디오·악기       계     10089         7412
# 19      미국     음반·비디오·악기     면세점         0            0
# 20      미국     음반·비디오·악기  면세점 이외     10089         7412
# 21      미국  의류 및 패션 관련상품       계     29729        21186
# 22      미국  의류 및 패션 관련상품     면세점        21            6
# 23      미국  의류 및 패션 관련상품  면세점 이외     29708        21180
# 24      미국      스포츠·레저용품       계       810          311
# 25      미국      스포츠·레저용품     면세점         0            0
# 26      미국      스포츠·레저용품  면세점 이외       810          311
# 27      미국           화장품       계      9963         7662
# 28      미국           화장품     면세점        51           99
# 29      미국           화장품  면세점 이외      9912         7563
# 30      미국       아동·유아용품       계       823          477
# 31      미국       아동·유아용품     면세점         0            0
# 32      미국       아동·유아용품  면세점 이외       823          477
# 33      미국         음·식료품       계       962          851
# 34      미국         음·식료품     면세점        35           22
# 35      미국         음·식료품  면세점 이외       927          829
# 36      미국         농축수산물       계         5           10
# 37      미국         농축수산물     면세점         0            0
# 38      미국         농축수산물  면세점 이외         5           10
# 39      미국  생활용품 및 자동차용품       계      1073          381
# 40      미국  생활용품 및 자동차용품     면세점         0            0
# 41      미국  생활용품 및 자동차용품  면세점 이외      1073          381
# 42      미국           기 타       계      8422         7119
# 43      미국           기 타     면세점         0            0
# 44      미국           기 타  면세점 이외      8422         7119

# %%
df_raw[(df_raw['국가(대륙)별'] == '미국') | (df_raw['국가(대륙)별'] == '중동')]
# Out:
#     국가(대륙)별          상품군별   판매유형별  2021.4/4  2022.1/4 p)
# 45       미국            합계       계     67036        50156
# 46       미국            합계     면세점       108          127
# 47       미국            합계  면세점 이외     66928        50029
# 48       미국    컴퓨터 및 주변기기       계       731          656
# 49       미국    컴퓨터 및 주변기기     면세점         0            0
# ..      ...           ...     ...       ...          ...
# 310      중동  생활용품 및 자동차용품     면세점         0            0
# 311      중동  생활용품 및 자동차용품  면세점 이외        60            4
# 312      중동           기 타       계        43           18
# 313      중동           기 타     면세점         0            0
# 314      중동           기 타  면세점 이외        43           18
#
# [90 rows x 5 columns]

# %% [markdown]
# * http://world.kbs.co.kr/service/news_view.htm?lang=k&Seq_Code=346701

# %%
# test
import pandas as pd

df = pd.DataFrame({'A':['a1','a2','a3','a4'],
                'B':['b1','b2','b3','b4'],
                'C':['1','2','3','4'],
                'D':['100','200','300','400']})
df
# Out:
#     A   B  C    D
# 0  a1  b1  1  100
# 1  a2  b2  2  200
# 2  a3  b3  3  300
# 3  a4  b4  4  400

# %%
df.melt(id_vars='A',value_vars='B')
# Out:
#     A variable value
# 0  a1        B    b1
# 1  a2        B    b2
# 2  a3        B    b3
# 3  a4        B    b4

# %%
df.melt(id_vars='A',value_vars='B',var_name='AA',value_name='BB')
# Out:
#     A AA  BB
# 0  a1  B  b1
# 1  a2  B  b2
# 2  a3  B  b3
# 3  a4  B  b4

# %%
df_raw
# Out:
#     국가(대륙)별          상품군별   판매유형별  2021.4/4  2022.1/4 p)
# 0        합계            합계       계    926718       567701
# 1        합계            합계     면세점    681168       363520
# 2        합계            합계  면세점 이외    245550       204181
# 3        합계    컴퓨터 및 주변기기       계      2707         2449
# 4        합계    컴퓨터 및 주변기기     면세점         0            0
# ..      ...           ...     ...       ...          ...
# 445      기타  생활용품 및 자동차용품     면세점         0            0
# 446      기타  생활용품 및 자동차용품  면세점 이외      1081          267
# 447      기타           기 타       계      1076         2309
# 448      기타           기 타     면세점         0            0
# 449      기타           기 타  면세점 이외      1076         2309
#
# [450 rows x 5 columns]

# %% [markdown]
# ### 데이터 전처리
# * 데이터 재배치

# %%
df = df_raw.melt(id_vars=['국가(대륙)별','상품군별','판매유형별'],var_name='기간',value_name='million')
df
# Out:
#     국가(대륙)별          상품군별   판매유형별           기간  million
# 0        합계            합계       계     2021.4/4   926718
# 1        합계            합계     면세점     2021.4/4   681168
# 2        합계            합계  면세점 이외     2021.4/4   245550
# 3        합계    컴퓨터 및 주변기기       계     2021.4/4     2707
# 4        합계    컴퓨터 및 주변기기     면세점     2021.4/4        0
# ..      ...           ...     ...          ...      ...
# 895      기타  생활용품 및 자동차용품     면세점  2022.1/4 p)        0
# 896      기타  생활용품 및 자동차용품  면세점 이외  2022.1/4 p)      267
# 897      기타           기 타       계  2022.1/4 p)     2309
# 898      기타           기 타     면세점  2022.1/4 p)        0
# 899      기타           기 타  면세점 이외  2022.1/4 p)     2309
#
# [900 rows x 5 columns]

# %% [markdown]
# * 기간에서 연도를 분리

# %%
"2019.3/4 p".split('.')
# Out:
# ['2019', '3/4 p']

# %%
df['연도'] = df['기간'].map(lambda x: x.split('.')[0])
df
# Out:
#     국가(대륙)별          상품군별   판매유형별           기간  million    연도
# 0        합계            합계       계     2021.4/4   926718  2021
# 1        합계            합계     면세점     2021.4/4   681168  2021
# 2        합계            합계  면세점 이외     2021.4/4   245550  2021
# 3        합계    컴퓨터 및 주변기기       계     2021.4/4     2707  2021
# 4        합계    컴퓨터 및 주변기기     면세점     2021.4/4        0  2021
# ..      ...           ...     ...          ...      ...   ...
# 895      기타  생활용품 및 자동차용품     면세점  2022.1/4 p)        0  2022
# 896      기타  생활용품 및 자동차용품  면세점 이외  2022.1/4 p)      267  2022
# 897      기타           기 타       계  2022.1/4 p)     2309  2022
# 898      기타           기 타     면세점  2022.1/4 p)        0  2022
# 899      기타           기 타  면세점 이외  2022.1/4 p)     2309  2022
#
# [900 rows x 6 columns]

# %%
df['분기'] = df['기간'].apply(lambda x: (x.split('.')[1]).split('/')[0])
df
# Out:
#     국가(대륙)별          상품군별   판매유형별           기간  million    연도 분기
# 0        합계            합계       계     2021.4/4   926718  2021  4
# 1        합계            합계     면세점     2021.4/4   681168  2021  4
# 2        합계            합계  면세점 이외     2021.4/4   245550  2021  4
# 3        합계    컴퓨터 및 주변기기       계     2021.4/4     2707  2021  4
# 4        합계    컴퓨터 및 주변기기     면세점     2021.4/4        0  2021  4
# ..      ...           ...     ...          ...      ...   ... ..
# 895      기타  생활용품 및 자동차용품     면세점  2022.1/4 p)        0  2022  1
# 896      기타  생활용품 및 자동차용품  면세점 이외  2022.1/4 p)      267  2022  1
# 897      기타           기 타       계  2022.1/4 p)     2309  2022  1
# 898      기타           기 타     면세점  2022.1/4 p)        0  2022  1
# 899      기타           기 타  면세점 이외  2022.1/4 p)     2309  2022  1
#
# [900 rows x 7 columns]

# %%
type(df['분기'].iloc[0])
# Out:
# str

# %% [markdown]
# * 금액 데이터 타입 변경

# %%
df['million'] = df['million'].replace('-',pd.np.nan).astype(float)
df
# Out:
# C:\Users\LEEBYC\AppData\Local\Temp\ipykernel_3720\1037084216.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['million'] = df['million'].replace('-',pd.np.nan).astype(float)
#     국가(대륙)별          상품군별   판매유형별           기간   million    연도 분기
# 0        합계            합계       계     2021.4/4  926718.0  2021  4
# 1        합계            합계     면세점     2021.4/4  681168.0  2021  4
# 2        합계            합계  면세점 이외     2021.4/4  245550.0  2021  4
# 3        합계    컴퓨터 및 주변기기       계     2021.4/4    2707.0  2021  4
# 4        합계    컴퓨터 및 주변기기     면세점     2021.4/4       0.0  2021  4
# ..      ...           ...     ...          ...       ...   ... ..
# 895      기타  생활용품 및 자동차용품     면세점  2022.1/4 p)       0.0  2022  1
# 896      기타  생활용품 및 자동차용품  면세점 이외  2022.1/4 p)     267.0  2022  1
# 897      기타           기 타       계  2022.1/4 p)    2309.0  2022  1
# 898      기타           기 타     면세점  2022.1/4 p)       0.0  2022  1
# 899      기타           기 타  면세점 이외  2022.1/4 p)    2309.0  2022  1
#
# [900 rows x 7 columns]

# %% [markdown]
# * 불필요한 데이터 제거

# %%
df = df[(df['국가(대륙)별'] != '합계') & (df['상품군별'] != '합계') & (df['판매유형별'] != '계')].copy()
df
# Out:
#     국가(대륙)별          상품군별   판매유형별           기간  million    연도 분기
# 49       미국    컴퓨터 및 주변기기     면세점     2021.4/4      0.0  2021  4
# 50       미국    컴퓨터 및 주변기기  면세점 이외     2021.4/4    731.0  2021  4
# 52       미국    가전·전자·통신기기     면세점     2021.4/4      1.0  2021  4
# 53       미국    가전·전자·통신기기  면세점 이외     2021.4/4    698.0  2021  4
# 55       미국         소프트웨어     면세점     2021.4/4      0.0  2021  4
# ..      ...           ...     ...          ...      ...   ... ..
# 893      기타         농축수산물  면세점 이외  2022.1/4 p)     10.0  2022  1
# 895      기타  생활용품 및 자동차용품     면세점  2022.1/4 p)      0.0  2022  1
# 896      기타  생활용품 및 자동차용품  면세점 이외  2022.1/4 p)    267.0  2022  1
# 898      기타           기 타     면세점  2022.1/4 p)      0.0  2022  1
# 899      기타           기 타  면세점 이외  2022.1/4 p)   2309.0  2022  1
#
# [504 rows x 7 columns]

# %%
df[df['상품군별'] == '소프트웨어']['million'].sum()
# Out:
# 427.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 504 entries, 49 to 899
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  504 non-null    object
#  1   상품군별     504 non-null    object
#  2   판매유형별    504 non-null    object
#  3   기간       504 non-null    object
#  4   million  504 non-null    float64
#  5   연도       504 non-null    object
#  6   분기       504 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 31.5+ KB

# %% [markdown]
# ## K-Beauty 시각화

# %% [markdown]
# * 전체 상품군 판매액

# %%
plt.figure(figsize=(15,4))
sns.lineplot(x='연도',y='million',data=df,hue='상품군별')
# Out:
# <Axes: xlabel='연도', ylabel='million'>

# %%
sns.relplot(x='연도',y='million',data=df,hue='상품군별',col='상품군별',col_wrap=4,kind='line')

# %%
df_sub = df[~df['상품군별'].isin(['화장품'])]
df_sub
# Out:
#     국가(대륙)별          상품군별   판매유형별           기간  million    연도 분기
# 49       미국    컴퓨터 및 주변기기     면세점     2021.4/4      0.0  2021  4
# 50       미국    컴퓨터 및 주변기기  면세점 이외     2021.4/4    731.0  2021  4
# 52       미국    가전·전자·통신기기     면세점     2021.4/4      1.0  2021  4
# 53       미국    가전·전자·통신기기  면세점 이외     2021.4/4    698.0  2021  4
# 55       미국         소프트웨어     면세점     2021.4/4      0.0  2021  4
# ..      ...           ...     ...          ...      ...   ... ..
# 893      기타         농축수산물  면세점 이외  2022.1/4 p)     10.0  2022  1
# 895      기타  생활용품 및 자동차용품     면세점  2022.1/4 p)      0.0  2022  1
# 896      기타  생활용품 및 자동차용품  면세점 이외  2022.1/4 p)    267.0  2022  1
# 898      기타           기 타     면세점  2022.1/4 p)      0.0  2022  1
# 899      기타           기 타  면세점 이외  2022.1/4 p)   2309.0  2022  1
#
# [468 rows x 7 columns]

# %%
sns.relplot(x='연도',y='million',data=df_sub,hue='상품군별',col='상품군별',col_wrap=4,kind='line')

# %% [markdown]
# * 화장품의 온라인쇼핑 해외직접판매액

# %%
df_cosmetic = df[(df['상품군별']=='화장품')]

plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
sns.lineplot(data=df_cosmetic,x='기간',y='million')
# Out:
# <Axes: xlabel='기간', ylabel='million'>

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
sns.lineplot(data=df_cosmetic,x='기간',y='million',hue='국가(대륙)별')
# Out:
# <Axes: xlabel='기간', ylabel='million'>

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
sns.lineplot(data=df_cosmetic,x='기간',y='million',hue='판매유형별')
# Out:
# <Axes: xlabel='기간', ylabel='million'>

# %% [markdown]
# * 의류 및 패션관련 상품 온라인쇼핑 해외직접판매액

# %%
df_fashion = df[df['상품군별'].str.contains('의류')]
plt.figure(figsize=(15,4))
plt.title('의류 및 패션관련 상품')
plt.xticks(rotation=30)
sns.lineplot(data=df_fashion,x='기간',y='million',hue='국가(대륙)별')
# Out:
# <Axes: title={'center': '의류 및 패션관련 상품'}, xlabel='기간', ylabel='million'>

# %%
sns.relplot(x='연도',y='million',data=df,hue='상품군별',col='상품군별',col_wrap=4,kind='line')

# %% [markdown]
# ### 데이터 집계하기

# %%
pivot = df_fashion.pivot_table(index='국가(대륙)별',values='million',columns='연도',aggfunc='sum')
pivot
# Out:
# 연도             2021     2022
# 국가(대륙)별
# 기타           2068.0   2139.0
# 대양주          1675.0   1581.0
# 미국          29729.0  21186.0
# 아세안(ASEAN)   7816.0   8574.0
# 유럽연합(EU)     1407.0   1600.0
# 일본          33780.0  26333.0
# 중국          24964.0  13868.0
# 중남미            95.0     47.0
# 중동            273.0    183.0

# %%
plt.figure(figsize=(15,7))
sns.heatmap(pivot, cmap='Blues',annot=True,fmt='.0f')
# Out:
# <Axes: xlabel='연도', ylabel='국가(대륙)별'>

# %%
sns.barplot(x='연도',y='million',data=df_sub)
# Out:
# <Axes: xlabel='연도', ylabel='million'>
